# %% [markdown]
# # Лабораторная работа 3

# %% [markdown]
# > =========================================
# >
# > Тема: Обработка текстов
# >
# > Набор данных: Комментарии к видео 4 направленностей - игры, влоги, обзоры техники, реакции
# >
# > Студент: Цветков Иван ИУ7-22М
# >
# >=========================================

# %% [markdown]
# ## 0. Импорты

# %%
import pandas as pd
import numpy as np
import re
import nltk
import pymorphy3
import math
import matplotlib.pyplot as plt
import seaborn as sns
import multiprocessing

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from gensim.models import Word2Vec
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize

# %%
# nltk.download("stopwords") # для первого запуска

# %% [markdown]
# ## 1. Данные

# %% [markdown]
# ### 1.1. Стопслова

# %%
stopWords = stopwords.words("russian")
stopWords.append("он")
stopWords.append("она")
stopWords.append("это")

morph = pymorphy3.MorphAnalyzer(lang='ru')

# %%
def delete_stop_words(text):
    return [word for word in text if word not in stopWords]

def format_data(text):
    fmtTextStr = re.sub(r'[^\w\s]', ' ', text.lower(), flags=re.UNICODE)
    tokenTextArr = nltk.word_tokenize(fmtTextStr)
    cleanTextArr = delete_stop_words(tokenTextArr)
    return " ".join(cleanTextArr)

# %%
def get_normalFormStr(line):
    return " ".join([morph.parse(word)[0].normal_form for word in line.split() if morph.parse(word)[0].normal_form not in stopWords])

# %% [markdown]
# ### 1.2. Чтение

# %%
def read_files(filename, format):
    i = 1
    dataArr = []
    while True:
        try:
            fd = open(filename + str(i) + format, encoding="utf-8")
        except Exception:
            break
        
        dataArr.append([i, fd.read()])
        
        fd.close()
        i += 1
    return dataArr

# %%
gameArr = read_files("./data/1-game_", ".txt")
vlogArr = read_files("./data/2-vlog_", ".txt")
techArr = read_files("./data/3-tech_", ".txt")
reactArr = read_files("./data/4-react_", ".txt")

# %% [markdown]
# ### 1.3. В DataFrame

# %%
gameDF = pd.DataFrame(gameArr, columns=['num_doc', 'text'])
gameDF["class"] = "game"

vlogDF = pd.DataFrame(vlogArr, columns=['num_doc', 'text'])
vlogDF["class"] = "vlog"

techDF = pd.DataFrame(techArr, columns=['num_doc', 'text'])
techDF["class"] = "tech"

reactDF = pd.DataFrame(reactArr, columns=['num_doc', 'text'])
reactDF["class"] = "react"

# %%
videosDF = pd.concat([gameDF, vlogDF, techDF, reactDF])
videosDF.head(10)
# Out:
#    num_doc                                               text class
# 0        1  Этот ролик просто поражает своей графикой и ат...  game
# 1        2  Впечатляющее видео! Я был поражен деталями в б...  game
# 2        3  Эта игра точно обещает стать новым эталоном в ...  game
# 3        4  Смотря на этот ролик, я просто не могу поверит...  game
# 4        5  Меня порадовало то, как игра балансирует между...  game
# 5        6  Один из самых впечатляющих аспектов этого роли...  game
# 6        7  Невероятно, как много деталей и внимания к мир...  game
# 7        8  Мне очень нравится то, как разнообразны возмож...  game
# 8        9  Очень впечатляющий ролик! Не могу не отметить ...  game
# 9       10  Я просто ошеломлен масштабом и красотой этого ...  game

# %% [markdown]
# ## 2. Выполнение

# %% [markdown]
# ### 2.1. Кластеризация

# %%
videosDF["formated"] = videosDF.text.apply(lambda textFTale: get_normalFormStr(format_data(textFTale)))
videosDF["formated_withoutMorph"] = videosDF.text.apply(lambda textFTale: format_data(textFTale))

# %%
def _getVectorizer(fieldName):
    vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5, max_df=0.95)
    x = vectorizer.fit_transform(videosDF[fieldName])
    return x

def _getClusters(x, fieldName):
    kmeans = KMeans(n_clusters=3, random_state=42)
    kmeans.fit(x)
    clusters = kmeans.labels_
    videosDF[fieldName] = clusters

def _pca(x, fieldX0, fieldX1, fieldCluster):
    pca = PCA(n_components=2, random_state=42)
    pca_vecs = pca.fit_transform(x.toarray())
    x0 = pca_vecs[:, 0]
    x1 = pca_vecs[:, 1]

    videosDF[fieldX0] = x0
    videosDF[fieldX1] = x1

    plt.figure(figsize=(12, 7))
    plt.title("TF-IDF")
    plt.xlabel(fieldX0)
    plt.ylabel(fieldX1)
    sns.scatterplot(data=videosDF, x=fieldX0, y=fieldX1, hue=fieldCluster, palette=['green', 'orange', 'dodgerblue'])
    plt.show()

def _calcAccuracy(x, fieldCluster):
    XVectorDf = pd.DataFrame(x.toarray())
    xTraining, xTest, yTraining, yTest = train_test_split(XVectorDf, videosDF[fieldCluster], test_size = 0.4, random_state=42)

    knn = KNeighborsClassifier(n_neighbors=3, weights='distance', metric='minkowski')
    knn.fit(xTraining, yTraining)
    predictions = knn.predict(xTest).tolist()

    print(accuracy_score(yTest, predictions))
    print(classification_report(yTest, predictions))


def processTfIdf(fieldData, fieldCluster, fieldX0, fieldX1):
    X = _getVectorizer(fieldData)
    _getClusters(X, fieldCluster)
    _pca(X, fieldX0, fieldX1, fieldCluster)
    _calcAccuracy(X, fieldCluster)
    


processTfIdf('formated', 'cluster', "x0", "x1")
processTfIdf('formated_withoutMorph', 'clusters_withoutMorph', "x0_withoutMorph", "x1_withoutMorph")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 0.875
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88         9
#            1       0.60      1.00      0.75         3
#            2       1.00      1.00      1.00         4
#
#     accuracy                           0.88        16
#    macro avg       0.87      0.93      0.88        16
# weighted avg       0.93      0.88      0.88        16
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         4
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %% [markdown]
# ### 2.2. Word2Vec

# %%
def _get_w2vdf(fieldData):
    w2v_df = pd.DataFrame(videosDF[fieldData]).values.tolist()
    for i in range(len(w2v_df)):
        w2v_df[i] = w2v_df[i][0].split(" ")
    return w2v_df

def _train_w2v(w2v_df):
    w2v_model = Word2Vec(min_count=1, vector_size=100)
    
    w2v_model.build_vocab(w2v_df)
    w2v_model.train(w2v_df, total_examples=w2v_model.corpus_count, epochs=100, report_delay=1)
    return w2v_model

def _preprocess(s):
    return [i for i in s.split()]

def _get_vector(s, model):
    return np.sum(np.array([model.wv[i] for i in _preprocess(s)]), axis=0)

def _pcaContext(x, fieldX0, fieldX1, fieldCluster):
    pca = PCA(n_components=2, random_state=42)
    pca_vecs = pca.fit_transform(x)
    x0 = pca_vecs[:, 0]
    x1 = pca_vecs[:, 1]


    videosDF[fieldX0] = x0
    videosDF[fieldX1] = x1

    plt.figure(figsize=(12, 7))
    plt.title("Word2Vec")
    plt.xlabel(fieldX0)
    plt.ylabel(fieldX1)
    sns.scatterplot(data=videosDF, x=fieldX0, y=fieldX1, hue=fieldCluster, palette=['green', 'orange', 'dodgerblue'])
    plt.show()

def _calcAccuracyContext(x, fieldCluster):
    XVectorDf = pd.DataFrame(x)
    xTraining, xTest, yTraining, yTest = train_test_split(XVectorDf, videosDF[fieldCluster], test_size = 0.4, random_state=42)

    knn = KNeighborsClassifier(n_neighbors=3, weights='distance', metric='minkowski')
    knn.fit(xTraining, yTraining)
    predictions = knn.predict(xTest).tolist()

    print(accuracy_score(yTest, predictions))
    print(classification_report(yTest, predictions))


def processContex(fieldData, fieldCluster, fieldX0, fieldX1):
    w2v_df = _get_w2vdf(fieldData)
    w2v_model = _train_w2v(w2v_df)

    x = [_get_vector(text, w2v_model) for text in videosDF[fieldData]]
    x = normalize(x)

    _getClusters(x, fieldCluster)
    _pcaContext(x, fieldX0, fieldX1, fieldCluster)
    _calcAccuracyContext(x, fieldCluster)

processContex("formated", "context_cluster", "context_x0", "context_x1")
processContex("formated_withoutMorph", "context_cluster_withoutMorph", "context_x0_withoutMorph", "context_x1_withoutMorph")

videosDF
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         2
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00        10
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16
#    num_doc                                               text  class  \
# 0        1  Этот ролик просто поражает своей графикой и ат...   game
# 1        2  Впечатляющее видео! Я был поражен деталями в б...   game
# 2        3  Эта игра точно обещает стать новым эталоном в ...   game
# 3        4  Смотря на этот ролик, я просто не могу поверит...   game
# 4        5  Меня порадовало то, как игра балансирует между...   game
# 5        6  Один из самых впечатляющих аспектов этого роли...   game
# 6        7  Невероятно, как много деталей и внимания к мир...   game
# 7        8  Мне очень нравится то, как разнообразны возмож...   game
# 8        9  Очень впечатляющий ролик! Не могу не отметить ...   game
# 9       10  Я просто ошеломлен масштабом и красотой этого ...   game
# 0        1  Этот влог просто потрясающий! Я наслаждался ка...   vlog
# 1        2  У этого влога такая приятная атмосфера! Видно,...   vlog
# 2        3  Этот влог просто излучает позитив и энергию! Я...   vlog
# 3        4  Очень интересный и информативный влог! Я узнал...   vlog
# 4        5  Смотря на этот влог, я просто захотел сразу па...   vlog
# 5        6  Этот влог - настоящее произведение искусства! ...   vlog
# 6        7  В этом влоге так много полезной информации! Я ...   vlog
# 7        8  Не могу нарадоваться этому влогу! Я почувствов...   vlog
# 8        9  Этот влог просто уникален! Я очень ценю автора...   vlog
# 9       10  Смотря на этот влог, я понял, что путешествия ...   vlog
# 0        1  Это видео обзор просто потрясающий! Я очень це...   tech
# 1        2  Спасибо за такой детальный обзор! Я всегда цен...   tech
# 2        3  Этот обзор просто великолепен! Очень понравила...   tech
# 3        4  Я впечатлен этим обзором! Очень радует, что ав...   tech
# 4        5  Смотря на этот обзор, я почувствовал себя как ...   tech
# 5        6  Этот обзор просто обязан быть у всех, кто инте...   tech
# 6        7  Очень информативный и профессиональный обзор! ...   tech
# 7        8  Я поражен уровнем детализации этого обзора! Ав...   tech
# 8        9  Этот обзор - просто кладезь полезной информаци...   tech
# 9       10  Спасибо за этот подробный и объективный обзор!...   tech
# 0        1  Это видео реакция просто удивительно заразител...  react
# 1        2  Я был в восторге от этой видео реакции! Автор ...  react
# 2        3  Это один из лучших видео реакций, которые я ко...  react
# 3        4  Не могу нарадоваться этому видео реакции! Очен...  react
# 4        5  Это видео реакции действительно выделяется из ...  react
# 5        6  Этот реакционный контент действительно вдохнов...  react
# 6        7  Каждая видео реакция от этого автора - настоящ...  react
# 7        8  Этот видео реакция - просто невероятный опыт! ...  react
# 8        9  Не могу перестать смотреть этот видео реакция!...  react
# 9       10  Это один из тех видео реакций, которые заставл...  react
#
#                                             formated  \
# 0  ролик просто поражать свой графика атмосфера к...
# 1  впечатляющий видео поразить деталь боевой сист...
# 2  игра точно обещать стать новый эталон жанр rpg...
# 3  смотреть ролик просто мочь поверить игра дело ...
# 4  порадовать игра балансировать сюжетный сцена и...
# 5  самый впечатляющий аспект ролик атмосфера прос...
# 6  невероятно деталь внимание мир игра каждый кад...
# 7  очень нравиться разнообразный возможность перс...
# 8  очень впечатляющий ролик мочь отметить работа ...
# 9  просто ошеломить масштаб красота мир ролик дей...
# 0  влог просто потрясать наслаждаться каждый мину...
# 1  влог приятный атмосфера видно автор настоящий ...
# 2  влог просто излучать позитив энергия полный во...
# 3  очень интересный информативный влог узнать нов...
# 4  смотреть влог просто захотеть сразу паковать ч...
# 5  влог настоящий произведение искусство каждый к...
# 6  влог полезный информация благодарный автор дел...
# 7  мочь нарадоваться влог почувствовать путешеств...
# 8  влог просто уникальный очень ценить автор креа...
# 9  смотреть влог понять путешествие просто поездк...
# 0  видео обзор просто потрясать очень ценить подр...
# 1  спасибо детальный обзор ценить автор выходить ...
# 2  обзор просто великолепный очень понравиться гл...
# 3  впечатлить обзор очень радовать автор подробно...
# 4  смотреть обзор почувствовать эксперт техника а...
# 5  обзор просто обязать интересоваться устройство...
# 6  очень информативный профессиональный обзор цен...
# 7  поразить уровень детализация обзор автор иссле...
# 8  обзор просто кладезь полезный информация оцени...
# 9  спасибо подробный объективный обзор ценить мне...
# 0  видео реакция просто удивительно заразительный...
# 1  восторг видео реакция автор ярко открыто выраж...
# 2  хороший видео реакция который либо видеть авто...
# 3  мочь нарадоваться видео реакция очень впечатля...
# 4  видео реакция действительно выделяться толпа ц...
# 5  реакционный контент действительно вдохновлять ...
# 6  каждый видео реакция автор настоящий произведе...
# 7  видео реакция просто невероятный опыт удивлённ...
# 8  мочь перестать смотреть видео реакция каждый н...
# 9  видео реакция который заставлять смеяться заду...
#
#                                formated_withoutMorph  cluster        x0  \
# 0  ролик просто поражает своей графикой атмосферо...        2  0.609043
# 1  впечатляющее видео поражен деталями боевой сис...        2  0.433069
# 2  эта игра точно обещает стать новым эталоном жа...        2  0.710315
# 3  смотря ролик просто могу поверить игра самом д...        2  0.547524
# 4  порадовало игра балансирует сюжетными сценами ...        2  0.668729
# 5  самых впечатляющих аспектов ролика атмосфера п...        2  0.640650
# 6  невероятно деталей внимания миру игры каждого ...        2  0.659415
# 7  очень нравится разнообразны возможности персон...        2  0.718896
# 8  очень впечатляющий ролик могу отметить работу ...        2  0.475540
# 9  просто ошеломлен масштабом красотой мира ролик...        2  0.540044
# 0  влог просто потрясающий наслаждался каждой мин...        0 -0.172486
# 1  влога такая приятная атмосфера видно автор нас...        0 -0.069168
# 2  влог просто излучает позитив энергию полном во...        0 -0.225754
# 3  очень интересный информативный влог узнал ново...        0 -0.225138
# 4  смотря влог просто захотел сразу паковать чемо...        0 -0.105406
# 5  влог настоящее произведение искусства каждый к...        0 -0.091117
# 6  влоге полезной информации благодарен автору де...        0 -0.207188
# 7  могу нарадоваться этому влогу почувствовал пут...        0 -0.075772
# 8  влог просто уникален очень ценю автора креатив...        0 -0.114234
# 9  смотря влог понял путешествия просто поездки ц...        0 -0.123026
# 0  видео обзор просто потрясающий очень ценю подр...        1 -0.342754
# 1  спасибо детальный обзор ценю авторы выходят пр...        1 -0.414289
# 2  обзор просто великолепен очень понравилась глу...        1 -0.262210
# 3  впечатлен этим обзором очень радует автор подр...        1 -0.392269
# 4  смотря обзор почувствовал эксперт технике авто...        1 -0.270229
# 5  обзор просто обязан интересуется этим устройст...        1 -0.347492
# 6  очень информативный профессиональный обзор цен...        1 -0.371188
# 7  поражен уровнем детализации обзора автор иссле...        1 -0.219859
# 8  обзор просто кладезь полезной информации оцени...        1 -0.354285
# 9  спасибо подробный объективный обзор ценю мнени...        1 -0.360375
# 0  видео реакция просто удивительно заразительное...        0 -0.110241
# 1  восторге видео реакции автор ярко открыто выра...        0 -0.129368
# 2  лучших видео реакций которые либо видел автор ...        0 -0.133995
# 3  могу нарадоваться этому видео реакции очень вп...        0 -0.119261
# 4  видео реакции действительно выделяется толпы ц...        0 -0.149618
# 5  реакционный контент действительно вдохновляет ...        0 -0.142910
# 6  каждая видео реакция автора настоящее произвед...        0 -0.175545
# 7  видео реакция просто невероятный опыт удивлен ...        0 -0.161129
# 8  могу перестать смотреть видео реакция каждый н...        0 -0.005516
# 9  тех видео реакций которые заставляют смеяться ...        0 -0.131405
#
#          x1  clusters_withoutMorph  x0_withoutMorph  x1_withoutMorph  \
# 0  0.079664                      2         0.624192        -0.181402
# 1 -0.058227                      2         0.498188        -0.037032
# 2  0.196696                      2         0.414401        -0.418683
# 3  0.083307                      2         0.426546         0.037677
# 4  0.176214                      2         0.616531        -0.440014
# 5  0.165714                      2         0.542698        -0.481560
# 6  0.175753                      2         0.542765        -0.455971
# 7  0.229044                      2         0.483602        -0.459152
# 8  0.073804                      2         0.371455        -0.102470
# 9  0.101423                      2         0.453805        -0.135003
# 0 -0.206692                      0        -0.096968         0.123799
# 1 -0.234968                      0        -0.031531         0.461056
# 2 -0.105504                      0        -0.027464         0.213503
# 3 -0.298354                      0        -0.139685         0.269105
# 4 -0.222125                      0        -0.149990         0.236636
# 5 -0.288625                      0        -0.029202         0.304054
# 6 -0.083882                      0        -0.031135         0.353145
# 7 -0.262109                      0         0.186146         0.220454
# 8 -0.158003                      0         0.034816         0.204883
# 9 -0.165992                      0        -0.154959         0.036035
# 0  0.410701                      1        -0.432882        -0.269430
# 1  0.530240                      1        -0.496021        -0.284846
# 2  0.547220                      1        -0.511390        -0.457663
# 3  0.641668                      1        -0.603323        -0.431024
# 4  0.291470                      1        -0.375555        -0.038960
# 5  0.282864                      1        -0.363533        -0.145683
# 6  0.545751                      1        -0.533066        -0.372109
# 7  0.460064                      1        -0.191820        -0.342687
# 8  0.629240                      1        -0.517756        -0.473092
# 9  0.273313                      1        -0.494276        -0.080687
# 0 -0.417079                      0         0.073499         0.176032
# 1 -0.434205                      0        -0.131942         0.409969
# 2 -0.490694                      0         0.125483         0.464373
# 3 -0.426394                      0        -0.010863         0.287361
# 4 -0.289376                      0        -0.154990         0.109969
# 5 -0.288870                      0        -0.111180         0.084497
# 6 -0.393015                      0        -0.159112         0.300021
# 7 -0.299061                      0         0.060735         0.344668
# 8 -0.280816                      0         0.212597         0.497099
# 9 -0.490160                      0         0.081184         0.473134
#
#    context_cluster  context_x0  context_x1  context_cluster_withoutMorph  \
# 0                1   -0.018566    0.013789                             0
# 1                1   -0.018412    0.007133                             0
# 2                1   -0.014426    0.009519                             0
# 3                1   -0.020408    0.012114                             2
# 4                1   -0.017140    0.012598                             0
# 5                1   -0.015457    0.012294                             0
# 6                1   -0.018115    0.019592                             0
# 7                1   -0.017172    0.011137                             0
# 8                1   -0.015768    0.008551                             0
# 9                1   -0.017130    0.016032                             0
# 0                0    0.000478   -0.010983                             2
# 1                0   -0.006562   -0.002082                             2
# 2                0    0.003144   -0.006991                             2
# 3                0    0.004188   -0.008974                             2
# 4                0    0.000212   -0.010876                             2
# 5                0   -0.009293   -0.007081                             2
# 6                0    0.010385   -0.007844                             2
# 7                0   -0.007530   -0.004347                             2
# 8                0   -0.007481    0.001072                             2
# 9                0   -0.000070   -0.000765                             2
# 0                2    0.023966    0.003372                             1
# 1                2    0.033677    0.008883                             1
# 2                2    0.021579    0.012265                             1
# 3                2    0.026092    0.006208                             1
# 4                2    0.013506   -0.002281                             2
# 5                0    0.005411    0.004411                             2
# 6                2    0.024928    0.014649                             1
# 7                2    0.007490    0.013853                             1
# 8                2    0.030320    0.016969                             1
# 9                2    0.024244   -0.002995                             1
# 0                0   -0.001981   -0.013812                             2
# 1                0   -0.004030   -0.017589                             2
# 2                0   -0.008590   -0.016909                             2
# 3                0   -0.009601   -0.016853                             2
# 4                0   -0.000298   -0.010689                             2
# 5                0    0.003458   -0.013113                             2
# 6                0   -0.000331   -0.015014                             2
# 7                0    0.003913   -0.008552                             2
# 8                0   -0.001368   -0.010385                             2
# 9                0   -0.007264   -0.016308                             2
#
#    context_x0_withoutMorph  context_x1_withoutMorph
# 0                -0.005601                 0.009779
# 1                -0.009276                 0.008353
# 2                -0.002314                 0.011520
# 3                -0.011738                 0.001029
# 4                -0.003163                 0.012128
# 5                -0.009350                 0.011193
# 6                -0.003685                 0.011797
# 7                -0.003814                 0.015309
# 8                -0.003738                 0.009654
# 9                -0.003328                 0.011047
# 0                -0.002863                -0.006751
# 1                -0.012073                -0.004529
# 2                 0.000865                -0.007467
# 3                 0.000013                -0.004702
# 4                 0.000770                -0.005552
# 5                -0.008486                -0.007815
# 6                 0.002287                -0.013497
# 7                -0.005936                -0.002116
# 8                -0.002777                -0.001148
# 9                -0.004354                -0.005340
# 0                 0.016817                 0.001659
# 1                 0.027466                 0.000116
# 2                 0.013680                 0.005725
# 3                 0.019235                -0.001022
# 4                 0.002491                -0.004390
# 5                 0.006106                -0.004260
# 6                 0.017414                 0.003907
# 7                 0.008390                 0.005898
# 8                 0.020900                -0.000062
# 9                 0.014503                -0.007255
# 0                -0.006044                -0.003212
# 1                -0.009756                -0.006365
# 2                -0.012458                -0.006929
# 3                -0.009471                 0.002537
# 4                -0.001577                -0.000976
# 5                 0.003928                -0.003390
# 6                -0.004634                -0.005694
# 7                 0.001466                -0.005432
# 8                -0.010058                -0.007003
# 9                -0.009837                -0.006744
